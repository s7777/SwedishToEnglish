# %%
import string
import re
from pickle import dump
from unicodedata import normalize
from numpy import array

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, mode='rt', encoding='utf-8')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# split a loaded document into sentences
def to_pairs(doc):
	lines = doc.strip().split('\n')
	pairs = [line.split('\t') for line in  lines]
	return pairs

# clean a list of lines
def clean_pairs(lines):
	cleaned = list()
	# prepare regex for char filtering
	#re_print = re.compile('[^%s]' % re.escape(string.printable))
	# prepare translation table for removing punctuation
	table = str.maketrans('', '', string.punctuation)
	for pair in lines:
		clean_pair = list()
		for line in pair:
			# normalize unicode characters
			#line = normalize('NFD', line).encode('ascii', 'ignore')
			#line = line.decode('UTF-8')
			# tokenize on white space
			line = line.split()
			# convert to lowercase
			#line = [word.lower() for word in line]
			# remove punctuation from each token
			line = [word.translate(table) for word in line]
			# remove non-printable chars form each token
			#line = [re_print.sub('', w) for w in line]
			# remove tokens with numbers in them
		#	line = [word for word in line if word.isalpha()]
			# store as string
			clean_pair.append(' '.join(line))
		cleaned.append(clean_pair)
	return array(cleaned)

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
filename = 'swe.txt'
doc = load_doc(filename)
# split into english-german pairs
pairs = to_pairs(doc)
# clean sentences
clean_pairs = clean_pairs(pairs)
# save clean pairs to file
save_clean_data(clean_pairs, 'english-Swedish.pkl')
# spot check
for i in range(100):
	print('[%s] => [%s]' % (clean_pairs[i,0], clean_pairs[i,1]))
# Out:
# Saved: english-Swedish.pkl
# [Go] => [Gå]
# [Run] => [Spring]
# [Who] => [Vem]
# [Help] => [Hjälp]
# [Jump] => [Hoppa]
# [Stop] => [Stanna]
# [Wait] => [Vänta]
# [Wait] => [Vänta]
# [Hurry] => [Skynda dig]
# [Hurry] => [Skynda]
# [Hurry] => [Skynda på]
# [I ran] => [Jag sprang]
# [I see] => [Jag förstår]
# [I see] => [Jag ser]
# [I won] => [Jag vann]
# [Relax] => [Slappna av]
# [Smile] => [Le]
# [Cheers] => [Skål]
# [He ran] => [Han sprang]
# [I swim] => [Jag simmar]
# [No way] => [Aldrig i livet]
# [Really] => [Är det sant]
# [Really] => [Jaså]
# [Thanks] => [Tack]
# [We try] => [Vi försöker]
# [Ask Tom] => [Fråga Tom]
# [Be cool] => [Ta det lugnt]
# [Be nice] => [Var trevlig]
# [Come in] => [Stig in]
# [Come on] => [Kom igen]
# [Drop it] => [Släpp det]
# [Get Tom] => [Hämta Tom]
# [Get out] => [Ut med dig]
# [Get out] => [Ut med er]
# [Go away] => [Gå iväg]
# [He runs] => [Han springer]
# [I agree] => [Jag håller med]
# [I agree] => [Jag instämmer]
# [Its OK] => [Det är okej]
# [Kiss me] => [Kyss mig]
# [Me too] => [Jag också]
# [Perfect] => [Perfekt]
# [See you] => [Vi ses]
# [Show me] => [Visa mig]
# [Tell me] => [Berätta för mig]
# [Wake up] => [Vakna]
# [Wash up] => [Tvätta dig]
# [We lost] => [Vi förlorade]
# [Back off] => [Sluta]
# [Back off] => [Lägg av]
# [Be still] => [Var still]
# [Be still] => [Stilla]
# [Can I go] => [Kan jag gå]
# [Cheer up] => [Ryck upp dig]
# [Cheer up] => [Ryck upp er]
# [Drive on] => [Kör vidare]
# [Find Tom] => [Hitta Tom]
# [Fix this] => [Fixa det här]
# [Fix this] => [Laga den här]
# [Get away] => [Stick]
# [Get away] => [Försvinn]
# [Get down] => [Ducka]
# [Get lost] => [Stick]
# [Get lost] => [Försvinn]
# [Go on in] => [Fortsätt in]
# [Grab Tom] => [Hugg tag i Tom]
# [Have fun] => [Ha det så roligt]
# [Humor me] => [Blidka mig]
# [Humor me] => [Gör mig till viljes]
# [Hurry up] => [Skynda dig]
# [Hurry up] => [Skynda]
# [I forgot] => [Jag glömde]
# [I got it] => [Jag förstår]
# [I jumped] => [Jag hoppade]
# [I nodded] => [Jag nickade]
# [I shaved] => [Jag rakade mig]
# [I stayed] => [Jag stannade kvar]
# [I stayed] => [Jag blev kvar]
# [I use it] => [Jag använder det]
# [Ill pay] => [Jag betalar]
# [Im busy] => [Jag är upptagen]
# [Im cold] => [Jag fryser]
# [Im deaf] => [Jag är döv]
# [Im fine] => [Det är okej med mig]
# [Im free] => [Jag är ledig]
# [Im free] => [Jag är fri]
# [Im full] => [Jag är mätt]
# [Im home] => [Jag är hemma]
# [Im late] => [Jag är sen]
# [Im next] => [Jag är nästa]
# [Im next] => [Jag är närmast i tur]
# [Im warm] => [Jag är varm]
# [It helps] => [Det hjälper]
# [It hurts] => [Det gör ont]
# [Its Tom] => [Det är Tom]
# [Its fun] => [Det är roligt]
# [Its fun] => [Det är kul]
# [Its fun] => [Det är skoj]
# [Its fun] => [Det är skojigt]
# [Kiss Tom] => [Kyss Tom]

# %%
from pickle import load
from pickle import dump
from numpy.random import rand
from numpy.random import shuffle

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# save a list of clean sentences to file
def save_clean_data(sentences, filename):
	dump(sentences, open(filename, 'wb'))
	print('Saved: %s' % filename)

# load dataset
raw_dataset = load_clean_sentences('english-Swedish.pkl')

# reduce dataset size
n_sentences = 10000
dataset = raw_dataset[:n_sentences, :]
# random shuffle
shuffle(dataset)
# split into train/test
train, test = dataset[:9000], dataset[1000:]
# save
save_clean_data(dataset, 'english-Swedish-both.pkl')
save_clean_data(train, 'english-Swedish-train.pkl')
save_clean_data(test, 'english-Swedish-test.pkl')
# Out:
# Saved: english-Swedish-both.pkl
# Saved: english-Swedish-train.pkl
# Saved: english-Swedish-test.pkl

# %%
from pickle import load
from numpy import array
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Embedding
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.callbacks import ModelCheckpoint

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# one hot encode target sequence
def encode_output(sequences, vocab_size):
	ylist = list()
	for sequence in sequences:
		encoded = to_categorical(sequence, num_classes=vocab_size)
		ylist.append(encoded)
	y = array(ylist)
	y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
	return y

# define NMT model
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
	model = Sequential()
	model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
	model.add(LSTM(n_units))
	model.add(RepeatVector(tar_timesteps))
	model.add(LSTM(n_units, return_sequences=True))
	model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
	return model

# load datasets
dataset = load_clean_sentences('english-Swedish-both.pkl')
train = load_clean_sentences('english-Swedish-train.pkl')
test = load_clean_sentences('english-Swedish-test.pkl')

# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
print('English Vocabulary Size: %d' % eng_vocab_size)
print('English Max Length: %d' % (eng_length))
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
print('Swedish  Vocabulary Size: %d' % ger_vocab_size)
print('Swedish  Max Length: %d' % (ger_length))

# prepare training data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 0])
trainY = encode_output(trainY, eng_vocab_size)
# prepare validation data
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])
testY = encode_sequences(eng_tokenizer, eng_length, test[:, 0])
testY = encode_output(testY, eng_vocab_size)

# define model
model = define_model(ger_vocab_size, eng_vocab_size, ger_length, eng_length, 256)
model.compile(optimizer='adam', loss='categorical_crossentropy')
# summarize defined model
print(model.summary())
plot_model(model, to_file='model.png', show_shapes=True)
# fit model
filename = 'model.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
model.fit(trainX, trainY, epochs=100, batch_size=64, validation_data=(testX, testY), callbacks=[checkpoint], verbose=2)
# Out:
# English Vocabulary Size: 2773
# English Max Length: 7
# Swedish  Vocabulary Size: 3868
# Swedish  Max Length: 10
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 10, 256)           990208
# _________________________________________________________________
# lstm (LSTM)                  (None, 256)               525312
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 7, 256)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 7, 256)            525312
# _________________________________________________________________
# time_distributed (TimeDistri (None, 7, 2773)           712661
# =================================================================
# Total params: 2,753,493
# Trainable params: 2,753,493
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 141/141 - 33s - loss: 4.0198 - val_loss: 3.2172
#
# Epoch 00001: val_loss improved from inf to 3.21718, saving model to model.h5
# Epoch 2/100
# 141/141 - 27s - loss: 3.1458 - val_loss: 3.0680
#
# Epoch 00002: val_loss improved from 3.21718 to 3.06805, saving model to model.h5
# Epoch 3/100
# 141/141 - 27s - loss: 3.0129 - val_loss: 2.9245
#
# Epoch 00003: val_loss improved from 3.06805 to 2.92452, saving model to model.h5
# Epoch 4/100
# 141/141 - 27s - loss: 2.8876 - val_loss: 2.8085
#
# Epoch 00004: val_loss improved from 2.92452 to 2.80852, saving model to model.h5
# Epoch 5/100
# 141/141 - 27s - loss: 2.7798 - val_loss: 2.7208
#
# Epoch 00005: val_loss improved from 2.80852 to 2.72081, saving model to model.h5
# Epoch 6/100
# 141/141 - 27s - loss: 2.6853 - val_loss: 2.6025
#
# Epoch 00006: val_loss improved from 2.72081 to 2.60248, saving model to model.h5
# Epoch 7/100
# 141/141 - 27s - loss: 2.5585 - val_loss: 2.4795
#
# Epoch 00007: val_loss improved from 2.60248 to 2.47947, saving model to model.h5
# Epoch 8/100
# 141/141 - 27s - loss: 2.4312 - val_loss: 2.3554
#
# Epoch 00008: val_loss improved from 2.47947 to 2.35537, saving model to model.h5
# Epoch 9/100
# 141/141 - 27s - loss: 2.3069 - val_loss: 2.2270
#
# Epoch 00009: val_loss improved from 2.35537 to 2.22702, saving model to model.h5
# Epoch 10/100
# 141/141 - 27s - loss: 2.1822 - val_loss: 2.1108
#
# Epoch 00010: val_loss improved from 2.22702 to 2.11082, saving model to model.h5
# Epoch 11/100
# 141/141 - 27s - loss: 2.0620 - val_loss: 1.9960
#
# Epoch 00011: val_loss improved from 2.11082 to 1.99602, saving model to model.h5
# Epoch 12/100
# 141/141 - 27s - loss: 1.9472 - val_loss: 1.8938
#
# Epoch 00012: val_loss improved from 1.99602 to 1.89380, saving model to model.h5
# Epoch 13/100
# 141/141 - 27s - loss: 1.8310 - val_loss: 1.7734
#
# Epoch 00013: val_loss improved from 1.89380 to 1.77345, saving model to model.h5
# Epoch 14/100
# 141/141 - 27s - loss: 1.7224 - val_loss: 1.6746
#
# Epoch 00014: val_loss improved from 1.77345 to 1.67461, saving model to model.h5
# Epoch 15/100
# 141/141 - 27s - loss: 1.6184 - val_loss: 1.5801
#
# Epoch 00015: val_loss improved from 1.67461 to 1.58010, saving model to model.h5
# Epoch 16/100
# 141/141 - 27s - loss: 1.5211 - val_loss: 1.4899
#
# Epoch 00016: val_loss improved from 1.58010 to 1.48985, saving model to model.h5
# Epoch 17/100
# 141/141 - 27s - loss: 1.4280 - val_loss: 1.4190
#
# Epoch 00017: val_loss improved from 1.48985 to 1.41900, saving model to model.h5
# Epoch 18/100
# 141/141 - 27s - loss: 1.3400 - val_loss: 1.3233
#
# Epoch 00018: val_loss improved from 1.41900 to 1.32329, saving model to model.h5
# Epoch 19/100
# 141/141 - 27s - loss: 1.2518 - val_loss: 1.2456
#
# Epoch 00019: val_loss improved from 1.32329 to 1.24565, saving model to model.h5
# Epoch 20/100
# 141/141 - 27s - loss: 1.1716 - val_loss: 1.1660
#
# Epoch 00020: val_loss improved from 1.24565 to 1.16604, saving model to model.h5
# Epoch 21/100
# 141/141 - 27s - loss: 1.0876 - val_loss: 1.0962
#
# Epoch 00021: val_loss improved from 1.16604 to 1.09617, saving model to model.h5
# Epoch 22/100
# 141/141 - 27s - loss: 1.0104 - val_loss: 1.0251
#
# Epoch 00022: val_loss improved from 1.09617 to 1.02513, saving model to model.h5
# Epoch 23/100
# 141/141 - 27s - loss: 0.9363 - val_loss: 0.9606
#
# Epoch 00023: val_loss improved from 1.02513 to 0.96060, saving model to model.h5
# Epoch 24/100
# 141/141 - 27s - loss: 0.8686 - val_loss: 0.9059
#
# Epoch 00024: val_loss improved from 0.96060 to 0.90592, saving model to model.h5
# Epoch 25/100
# 141/141 - 27s - loss: 0.8049 - val_loss: 0.8430
#
# Epoch 00025: val_loss improved from 0.90592 to 0.84298, saving model to model.h5
# Epoch 26/100
# 141/141 - 27s - loss: 0.7405 - val_loss: 0.7937
#
# Epoch 00026: val_loss improved from 0.84298 to 0.79366, saving model to model.h5
# Epoch 27/100
# 141/141 - 27s - loss: 0.6844 - val_loss: 0.7457
#
# Epoch 00027: val_loss improved from 0.79366 to 0.74568, saving model to model.h5
# Epoch 28/100
# 141/141 - 27s - loss: 0.6321 - val_loss: 0.7019
#
# Epoch 00028: val_loss improved from 0.74568 to 0.70195, saving model to model.h5
# Epoch 29/100
# 141/141 - 27s - loss: 0.5810 - val_loss: 0.6579
#
# Epoch 00029: val_loss improved from 0.70195 to 0.65793, saving model to model.h5
# Epoch 30/100
# 141/141 - 27s - loss: 0.5363 - val_loss: 0.6204
#
# Epoch 00030: val_loss improved from 0.65793 to 0.62045, saving model to model.h5
# Epoch 31/100
# 141/141 - 27s - loss: 0.4935 - val_loss: 0.5875
#
# Epoch 00031: val_loss improved from 0.62045 to 0.58752, saving model to model.h5
# Epoch 32/100
# 141/141 - 27s - loss: 0.4554 - val_loss: 0.5546
#
# Epoch 00032: val_loss improved from 0.58752 to 0.55458, saving model to model.h5
# Epoch 33/100
# 141/141 - 27s - loss: 0.4173 - val_loss: 0.5227
#
# Epoch 00033: val_loss improved from 0.55458 to 0.52265, saving model to model.h5
# Epoch 34/100
# 141/141 - 27s - loss: 0.3843 - val_loss: 0.4971
#
# Epoch 00034: val_loss improved from 0.52265 to 0.49711, saving model to model.h5
# Epoch 35/100
# 141/141 - 27s - loss: 0.3551 - val_loss: 0.4769
#
# Epoch 00035: val_loss improved from 0.49711 to 0.47691, saving model to model.h5
# Epoch 36/100
# 141/141 - 27s - loss: 0.3237 - val_loss: 0.4507
#
# Epoch 00036: val_loss improved from 0.47691 to 0.45070, saving model to model.h5
# Epoch 37/100
# 141/141 - 27s - loss: 0.2974 - val_loss: 0.4313
#
# Epoch 00037: val_loss improved from 0.45070 to 0.43129, saving model to model.h5
# Epoch 38/100
# 141/141 - 27s - loss: 0.2740 - val_loss: 0.4191
#
# Epoch 00038: val_loss improved from 0.43129 to 0.41910, saving model to model.h5
# Epoch 39/100
# 141/141 - 27s - loss: 0.2536 - val_loss: 0.3966
#
# Epoch 00039: val_loss improved from 0.41910 to 0.39665, saving model to model.h5
# Epoch 40/100
# 141/141 - 27s - loss: 0.2348 - val_loss: 0.3843
#
# Epoch 00040: val_loss improved from 0.39665 to 0.38426, saving model to model.h5
# Epoch 41/100
# 141/141 - 27s - loss: 0.2191 - val_loss: 0.3677
#
# Epoch 00041: val_loss improved from 0.38426 to 0.36774, saving model to model.h5
# Epoch 42/100
# 141/141 - 27s - loss: 0.1998 - val_loss: 0.3590
#
# Epoch 00042: val_loss improved from 0.36774 to 0.35900, saving model to model.h5
# Epoch 43/100
# 141/141 - 27s - loss: 0.1877 - val_loss: 0.3521
#
# Epoch 00043: val_loss improved from 0.35900 to 0.35205, saving model to model.h5
# Epoch 44/100
# 141/141 - 27s - loss: 0.1720 - val_loss: 0.3415
#
# Epoch 00044: val_loss improved from 0.35205 to 0.34152, saving model to model.h5
# Epoch 45/100
# 141/141 - 27s - loss: 0.1637 - val_loss: 0.3356
#
# Epoch 00045: val_loss improved from 0.34152 to 0.33555, saving model to model.h5
# Epoch 46/100
# 141/141 - 27s - loss: 0.1509 - val_loss: 0.3190
#
# Epoch 00046: val_loss improved from 0.33555 to 0.31897, saving model to model.h5
# Epoch 47/100
# 141/141 - 27s - loss: 0.1375 - val_loss: 0.3122
#
# Epoch 00047: val_loss improved from 0.31897 to 0.31224, saving model to model.h5
# Epoch 48/100
# 141/141 - 27s - loss: 0.1291 - val_loss: 0.3033
#
# Epoch 00048: val_loss improved from 0.31224 to 0.30334, saving model to model.h5
# Epoch 49/100
# 141/141 - 27s - loss: 0.1212 - val_loss: 0.3007
#
# Epoch 00049: val_loss improved from 0.30334 to 0.30071, saving model to model.h5
# Epoch 50/100
# 141/141 - 27s - loss: 0.1120 - val_loss: 0.2942
#
# Epoch 00050: val_loss improved from 0.30071 to 0.29423, saving model to model.h5
# Epoch 51/100
# 141/141 - 27s - loss: 0.1054 - val_loss: 0.2863
#
# Epoch 00051: val_loss improved from 0.29423 to 0.28628, saving model to model.h5
# Epoch 52/100
# 141/141 - 27s - loss: 0.0988 - val_loss: 0.2873
#
# Epoch 00052: val_loss did not improve from 0.28628
# Epoch 53/100
# 141/141 - 27s - loss: 0.0933 - val_loss: 0.2813
#
# Epoch 00053: val_loss improved from 0.28628 to 0.28127, saving model to model.h5
# Epoch 54/100
# 141/141 - 27s - loss: 0.0902 - val_loss: 0.2823
#
# Epoch 00054: val_loss did not improve from 0.28127
# Epoch 55/100
# 141/141 - 27s - loss: 0.0857 - val_loss: 0.2740
#
# Epoch 00055: val_loss improved from 0.28127 to 0.27397, saving model to model.h5
# Epoch 56/100
# 141/141 - 27s - loss: 0.0792 - val_loss: 0.2730
#
# Epoch 00056: val_loss improved from 0.27397 to 0.27295, saving model to model.h5
# Epoch 57/100
# 141/141 - 27s - loss: 0.0751 - val_loss: 0.2705
#
# Epoch 00057: val_loss improved from 0.27295 to 0.27046, saving model to model.h5
# Epoch 58/100
# 141/141 - 27s - loss: 0.0727 - val_loss: 0.2682
#
# Epoch 00058: val_loss improved from 0.27046 to 0.26818, saving model to model.h5
# Epoch 59/100
# 141/141 - 27s - loss: 0.0704 - val_loss: 0.2678
#
# Epoch 00059: val_loss improved from 0.26818 to 0.26781, saving model to model.h5
# Epoch 60/100
# 141/141 - 27s - loss: 0.0693 - val_loss: 0.2701
#
# Epoch 00060: val_loss did not improve from 0.26781
# Epoch 61/100
# 141/141 - 27s - loss: 0.0682 - val_loss: 0.2704
#
# Epoch 00061: val_loss did not improve from 0.26781
# Epoch 62/100
# 141/141 - 27s - loss: 0.0644 - val_loss: 0.2656
#
# Epoch 00062: val_loss improved from 0.26781 to 0.26562, saving model to model.h5
# Epoch 63/100
# 141/141 - 27s - loss: 0.0625 - val_loss: 0.2638
#
# Epoch 00063: val_loss improved from 0.26562 to 0.26380, saving model to model.h5
# Epoch 64/100
# 141/141 - 27s - loss: 0.0609 - val_loss: 0.2672
#
# Epoch 00064: val_loss did not improve from 0.26380
# Epoch 65/100
# 141/141 - 27s - loss: 0.0597 - val_loss: 0.2645
#
# Epoch 00065: val_loss did not improve from 0.26380
# Epoch 66/100
# 141/141 - 27s - loss: 0.0577 - val_loss: 0.2645
#
# Epoch 00066: val_loss did not improve from 0.26380
# Epoch 67/100
# 141/141 - 27s - loss: 0.0561 - val_loss: 0.2618
#
# Epoch 00067: val_loss improved from 0.26380 to 0.26175, saving model to model.h5
# Epoch 68/100
# 141/141 - 27s - loss: 0.0536 - val_loss: 0.2612
#
# Epoch 00068: val_loss improved from 0.26175 to 0.26121, saving model to model.h5
# Epoch 69/100
# 141/141 - 27s - loss: 0.0530 - val_loss: 0.2609
#
# Epoch 00069: val_loss improved from 0.26121 to 0.26089, saving model to model.h5
# Epoch 70/100
# 141/141 - 27s - loss: 0.0508 - val_loss: 0.2600
#
# Epoch 00070: val_loss improved from 0.26089 to 0.26000, saving model to model.h5
# Epoch 71/100
# 141/141 - 27s - loss: 0.0518 - val_loss: 0.2607
#
# Epoch 00071: val_loss did not improve from 0.26000
# Epoch 72/100
# 141/141 - 27s - loss: 0.0512 - val_loss: 0.2618
#
# Epoch 00072: val_loss did not improve from 0.26000
# Epoch 73/100
# 141/141 - 27s - loss: 0.0501 - val_loss: 0.2592
#
# Epoch 00073: val_loss improved from 0.26000 to 0.25919, saving model to model.h5
# Epoch 74/100
# 141/141 - 27s - loss: 0.0486 - val_loss: 0.2592
#
# Epoch 00074: val_loss did not improve from 0.25919
# Epoch 75/100
# 141/141 - 27s - loss: 0.0487 - val_loss: 0.2630
#
# Epoch 00075: val_loss did not improve from 0.25919
# Epoch 76/100
# 141/141 - 27s - loss: 0.0498 - val_loss: 0.2657
#
# Epoch 00076: val_loss did not improve from 0.25919
# Epoch 77/100
# 141/141 - 27s - loss: 0.0523 - val_loss: 0.2634
#
# Epoch 00077: val_loss did not improve from 0.25919
# Epoch 78/100
# 141/141 - 27s - loss: 0.0521 - val_loss: 0.2632
#
# Epoch 00078: val_loss did not improve from 0.25919
# Epoch 79/100
# 141/141 - 27s - loss: 0.0506 - val_loss: 0.2668
#
# Epoch 00079: val_loss did not improve from 0.25919
# Epoch 80/100
# 141/141 - 27s - loss: 0.0517 - val_loss: 0.2627
#
# Epoch 00080: val_loss did not improve from 0.25919
# Epoch 81/100
# 141/141 - 27s - loss: 0.0472 - val_loss: 0.2622
#
# Epoch 00081: val_loss did not improve from 0.25919
# Epoch 82/100
# 141/141 - 27s - loss: 0.0436 - val_loss: 0.2604
#
# Epoch 00082: val_loss did not improve from 0.25919
# Epoch 83/100
# 141/141 - 27s - loss: 0.0415 - val_loss: 0.2577
#
# Epoch 00083: val_loss improved from 0.25919 to 0.25773, saving model to model.h5
# Epoch 84/100
# 141/141 - 27s - loss: 0.0410 - val_loss: 0.2569
#
# Epoch 00084: val_loss improved from 0.25773 to 0.25693, saving model to model.h5
# Epoch 85/100
# 141/141 - 27s - loss: 0.0394 - val_loss: 0.2561
#
# Epoch 00085: val_loss improved from 0.25693 to 0.25615, saving model to model.h5
# Epoch 86/100
# 141/141 - 27s - loss: 0.0391 - val_loss: 0.2568
#
# Epoch 00086: val_loss did not improve from 0.25615
# Epoch 87/100
# 141/141 - 27s - loss: 0.0389 - val_loss: 0.2581
#
# Epoch 00087: val_loss did not improve from 0.25615
# Epoch 88/100
# 141/141 - 27s - loss: 0.0383 - val_loss: 0.2563
#
# Epoch 00088: val_loss did not improve from 0.25615
# Epoch 89/100
# 141/141 - 27s - loss: 0.0380 - val_loss: 0.2582
#
# Epoch 00089: val_loss did not improve from 0.25615
# Epoch 90/100
# 141/141 - 27s - loss: 0.0380 - val_loss: 0.2575
#
# Epoch 00090: val_loss did not improve from 0.25615
# Epoch 91/100
# 141/141 - 27s - loss: 0.0381 - val_loss: 0.2586
#
# Epoch 00091: val_loss did not improve from 0.25615
# Epoch 92/100
# 141/141 - 27s - loss: 0.0390 - val_loss: 0.2592
#
# Epoch 00092: val_loss did not improve from 0.25615
# Epoch 93/100
# 141/141 - 27s - loss: 0.0516 - val_loss: 0.2879
#
# Epoch 00093: val_loss did not improve from 0.25615
# Epoch 94/100
# 141/141 - 27s - loss: 0.0867 - val_loss: 0.2916
#
# Epoch 00094: val_loss did not improve from 0.25615
# Epoch 95/100
# 141/141 - 27s - loss: 0.0678 - val_loss: 0.2691
#
# Epoch 00095: val_loss did not improve from 0.25615
# Epoch 96/100
# 141/141 - 27s - loss: 0.0448 - val_loss: 0.2597
#
# Epoch 00096: val_loss did not improve from 0.25615
# Epoch 97/100
# 141/141 - 27s - loss: 0.0382 - val_loss: 0.2598
#
# Epoch 00097: val_loss did not improve from 0.25615
# Epoch 98/100
# 141/141 - 27s - loss: 0.0357 - val_loss: 0.2583
#
# Epoch 00098: val_loss did not improve from 0.25615
# Epoch 99/100
# 141/141 - 27s - loss: 0.0348 - val_loss: 0.2569
#
# Epoch 00099: val_loss did not improve from 0.25615
# Epoch 100/100
# 141/141 - 27s - loss: 0.0343 - val_loss: 0.2595
#
# Epoch 00100: val_loss did not improve from 0.25615

# %%
from pickle import load
from numpy import array
from numpy import argmax
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import load_model
from nltk.translate.bleu_score import corpus_bleu

# load a clean dataset
def load_clean_sentences(filename):
	return load(open(filename, 'rb'))

# fit a tokenizer
def create_tokenizer(lines):
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# max sentence length
def max_length(lines):
	return max(len(line.split()) for line in lines)

# encode and pad sequences
def encode_sequences(tokenizer, length, lines):
	# integer encode sequences
	X = tokenizer.texts_to_sequences(lines)
	# pad sequences with 0 values
	X = pad_sequences(X, maxlen=length, padding='post')
	return X

# map an integer to a word
def word_for_id(integer, tokenizer):
	for word, index in tokenizer.word_index.items():
		if index == integer:
			return word
	return None

# generate target given source sequence
def predict_sequence(model, tokenizer, source):
	prediction = model.predict(source, verbose=0)[0]
	integers = [argmax(vector) for vector in prediction]
	target = list()
	for i in integers:
		word = word_for_id(i, tokenizer)
		if word is None:
			break
		target.append(word)
	return ' '.join(target)

# evaluate the skill of the model
def evaluate_model(model, tokenizer, sources, raw_dataset):
	actual, predicted = list(), list()
	for i, source in enumerate(sources):
		# translate encoded source text
		source = source.reshape((1, source.shape[0]))
		translation = predict_sequence(model, eng_tokenizer, source)
		raw_target, raw_src,test = raw_dataset[i]
		if i < 10:
			print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
		actual.append([raw_target.split()])
		predicted.append(translation.split())
	# calculate BLEU score
	print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
	print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
	print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
	print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))

# load datasets
dataset = load_clean_sentences('english-Swedish-both.pkl')
train = load_clean_sentences('english-Swedish-train.pkl')
test = load_clean_sentences('english-Swedish-test.pkl')
# prepare english tokenizer
eng_tokenizer = create_tokenizer(dataset[:, 0])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 0])
# prepare german tokenizer
ger_tokenizer = create_tokenizer(dataset[:, 1])
ger_vocab_size = len(ger_tokenizer.word_index) + 1
ger_length = max_length(dataset[:, 1])
# prepare data
trainX = encode_sequences(ger_tokenizer, ger_length, train[:, 1])
testX = encode_sequences(ger_tokenizer, ger_length, test[:, 1])

# load model
model = load_model('model.h5')
# test on some training sequences
print('train')
evaluate_model(model, eng_tokenizer, trainX, train)
# test on some test sequences
print('test')
evaluate_model(model, eng_tokenizer, testX, test)
# Out:
# train
# src=[Hur fort sprang Tom], target=[How fast did Tom run], predicted=[how fast did tom run]
# src=[Det är inte relaterat], target=[Thats unrelated], predicted=[thats unrelated]
# src=[Jag tycker inte om hundar], target=[I dont like dogs], predicted=[i dont like dogs]
# src=[Hur upptagen kan Tom vara], target=[How busy could Tom be], predicted=[how busy could tom be]
# src=[Jag är glad att vi hittade er], target=[Im glad we found you], predicted=[im glad we found you]
# src=[Jag hatar annonser], target=[I hate advertisements], predicted=[i hate advertisements]
# src=[Var är han], target=[Where is he], predicted=[where is he]
# src=[Jag vill bara vara till hjälp], target=[I only wish to help], predicted=[i only wish to help]
# src=[Jag är färdig med det], target=[Im finished with it], predicted=[im finished with it]
# src=[Jag har inte på mig det här], target=[Im not wearing this], predicted=[im not wearing this]
# BLEU-1: 0.683189
# BLEU-2: 0.616865
# BLEU-3: 0.559377
# BLEU-4: 0.365442
# test
# src=[Vila dig här en stund], target=[Rest here for a bit], predicted=[rest here for a bit]
# src=[Frukosten är färdig], target=[Breakfast is ready], predicted=[breakfast is ready]
# src=[Jag är ledig i kväll], target=[Ill be free tonight], predicted=[ill be free tonight]
# src=[Hur hade Tom sovit], target=[How did Tom sleep], predicted=[how did tom sleep]
# src=[Jag kan ta hand om det där], target=[I can handle that], predicted=[i can handle that]
# src=[Det är inget misstag], target=[Its not a mistake], predicted=[its not a mistake]
# src=[Är Tom fortfarande singel], target=[Is Tom still single], predicted=[is tom still single]
# src=[Vi har problem], target=[Were in trouble], predicted=[were in trouble]
# src=[Det verkar som om han är trött], target=[He seems tired], predicted=[he seems tired]
# src=[Var punktlig], target=[Be punctual], predicted=[be punctual]
# BLEU-1: 0.648968
# BLEU-2: 0.579126
# BLEU-3: 0.525075
# BLEU-4: 0.339886
